# %% [markdown]
# # Theory
#
# We covered *classification* so far, whose purpose it to group the output into some classes. Now, we swith to *regression*-type example.
#
# ![classification.png](data:image/png;base64,...)
#
# *Linear regression* is used to predict continuous values based on a line which best models the relationship between the independent *X* and the dependent variable *Y*. The line which best fit a series of points. In another words, linear regression helps predict values on a continuous spectrum, rather than discrete classes.
#
# Linear regression is the simplest form of regression. The goal is to find a line parametrized by some set of *slope* and *y-intercept* parameters, which provide the best fit to our training data. With the trained network, it can now produce one output, which is the prediction for unlabeled test input.
#
# ![linear_regression.png](data:image/png;base64,...)
#
# However, how would we traine a neural network to perform linear regression? It does by minimizing the *loss* over dataset, whcih would correspond to *mean squared error*.

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential

# %% [markdown]
# In this regression-type example, we will train the neural network to fit a model into this non-linear data.
#
# ![nonlinear_dataset.png](data:image/png;base64,...)

# %%
np.random.seed(0)

points = 500  # number of points

X = np.linspace(-3, 3, points)  # range

# y = np.sin(X)  # To get a sinusoidal curve (sine wave)
# Adding some noise to our data so that each point in this curve can deviate
# from its standard shape, by adding variants that simply challenges our neural
# network, making it more difficult to learn.
y = np.sin(X) + np.random.uniform(-0.5, 0.5, points)

plt.scatter(X, y)
